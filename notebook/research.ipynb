# %%
print("ok")
# Out:
# ok

# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19460\1587769067.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
rating = pd.read_csv('ratings.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
userss = pd.read_csv('users.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
userss.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.iloc[5]['Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0399135782.01.LZZZZZZZ.jpg'

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.describe
# Out:
# <bound method NDFrame.describe of               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# ...

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
books.duplicated().sum()
# Out:
# 0

# %%
rating.duplicated().sum()
# Out:
# 0

# %%
userss.duplicated().sum()
# Out:
# 0

# %%
rating.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
rating.count()
# Out:
# User-ID        1149780
# ISBN           1149780
# Book-Rating    1149780
# dtype: int64

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
userss.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
books=books[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher','Image-URL-L']]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.rename(columns={"Book-Title" :'title',
              "Book-Author":'author',
              "Year-Of-Publication":'year',
              "Image-URL-L": 'image'},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19460\1303086923.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books.rename(columns={"Book-Title" :'title',

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   Publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                                image
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
rating.count()
# Out:
# User-ID        1149780
# ISBN           1149780
# Book-Rating    1149780
# dtype: int64

# %%
rating.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
(rating['Book-Rating'] == 0).sum()
# Out:
# 716109

# %%
rating.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1149775    False
# 1149776    False
# 1149777    False
# 1149778    False
# 1149779    False
# Length: 1149780, dtype: bool

# %%
rating['User-ID'].value_counts()
# Out:
# User-ID
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
user_11676_books = rating[rating['User-ID'] == 11676 ]
user_11676_books
# Out:
#        User-ID            ISBN  Book-Rating
# 45326    11676      9022906116            7
# 45327    11676  \0432534220\""            6
# 45328    11676  \2842053052\""            7
# 45329    11676   0 7336 1053 6            0
# 45330    11676     0=965044153            7
# ...        ...             ...          ...
# 58923    11676      O77O428452            0
# 58924    11676      O805063196            0
# 58925    11676       O9088446X            8
# 58926    11676      X000000000           10
# 58927    11676     ZR903CX0003            1
#
# [13602 rows x 3 columns]

# %%
#filtering users who had at least rated more than 200 books
x= rating['User-ID'].value_counts() >200
x
# Out:
# User-ID
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y= rating['User-ID'].value_counts() <200
y
# Out:
# User-ID
# 11676     False
# 198711    False
# 153662    False
# 98391     False
# 35859     False
#           ...
# 116180     True
# 116166     True
# 116154     True
# 116137     True
# 276723     True
# Name: count, Length: 105283, dtype: bool

# %%
y[y].shape
# Out:
# (104378,)

# %%
w=x[x].index
ratings=rating[rating['User-ID'].isin(w)]
ratings
# Out:
#          User-ID        ISBN  Book-Rating
# 1456      277427  002542730X           10
# 1457      277427  0026217457            0
# 1458      277427  003008685X            8
# 1459      277427  0030615321            0
# 1460      277427  0060002050            0
# ...          ...         ...          ...
# 1147612   275970  3829021860            0
# 1147613   275970  4770019572            0
# 1147614   275970   896086097            0
# 1147615   275970  9626340762            8
# 1147616   275970  9626344990            0
#
# [526356 rows x 3 columns]

# %%
# join 2 tables
rating_books = rating.merge(books,on='ISBN')
rating_books
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                      title           author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
number_rating= rating_books.groupby('title')['Book-Rating'].count().reset_index()
number_rating
# Out:
#                                                     title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
# I stoped here
final_rating= rating_books.merge(number_rating,on='title')

# %%
final_rating.head()
# Out:
#    User-ID        ISBN  Book-Rating_x                 title      author  year  \
# 0   276725  034545104X              0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X              5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X              0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X              5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X              9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher                                              image  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    Book-Rating_y
# 0             60
# 1             60
# ...

# %%
final_rating.rename(columns={"Book-Rating_y" :'number of rating'},inplace=True)

# %%
final_rating= final_rating[final_rating['number of rating']>=50]
final_rating.head()
# Out:
#    User-ID        ISBN  Book-Rating_x                 title      author  year  \
# 0   276725  034545104X              0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X              5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X              0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X              5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X              9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher                                              image  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    number of rating
# 0                60
# 1                60
# ...

# %%
final_rating.duplicated(subset=['User-ID', 'title']).sum()
# Out:
# 3222

# %%
final_rating[final_rating.duplicated(subset=['User-ID', 'title'], keep=False)]
# Out:
#         User-ID        ISBN  Book-Rating_x                 title  \
# 75       278418  0446520802              0          The Notebook
# 78         7158  0446520802             10          The Notebook
# 81        11676  0446520802             10          The Notebook
# 112      102967  0446520802              0          The Notebook
# 114      105979  0446520802              0          The Notebook
# ...         ...         ...            ...                   ...
# 671658    94923  0515123471              0        10 Lb. Penalty
# 671662   128835  0515123471              9        10 Lb. Penalty
# 671675   198711  0515123471              0        10 Lb. Penalty
# 730499   227447  5557121005              0  Love in Another Town
# 730560   227447  0061092096              0  Love in Another Town
#
#                          author  year      Publisher  \
# 75              Nicholas Sparks  1996   Warner Books
# 78              Nicholas Sparks  1996   Warner Books
# ...

# %%
#drop duplicates
final_rating.drop_duplicates(['User-ID','title'],inplace=True)

# %%
final_rating[final_rating.duplicated(subset=['User-ID', 'title'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [User-ID, ISBN, Book-Rating_x, title, author, year, Publisher, image, number of rating]
# Index: []

# %%
# Missing values
final_rating.isnull().sum()
# Out:
# User-ID             0
# ISBN                0
# Book-Rating_x       0
# title               0
# author              0
# year                0
# Publisher           0
# image               0
# number of rating    0
# dtype: int64

# %%
final_rating.rename(columns={"Book-Rating_x" :'rating'},inplace=True)

# %%
#clustering technique, collaborative filtering : we have to convert this data to the pivot table
book_pivot= final_rating.pivot_table(columns='User-ID',index='title',values='rating')

# %%
book_pivot
# Out:
# User-ID                                             8       9       14      \
# title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (2444, 47994)

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# User-ID                                             8       9       14      \
# title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
#convert to CSR matrix for the CNN to able to work 
book_sparse=csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <2444x47994 sparse matrix of type '<class 'numpy.float64'>'
# 	with 113444 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model= NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
book_pivot.iloc[237,:]
# Out:
# User-ID
# 8         0.0
# 9         6.0
# 14        0.0
# 16        0.0
# 17        0.0
#          ...
# 278843    0.0
# 278844    0.0
# 278846    0.0
# 278851    0.0
# 278854    0.0
# Name: Beloved (Plume Contemporary Fiction), Length: 47994, dtype: float64

# %%
distance, suggestion =model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6)
# Out:
# c:\Users\HP\anaconda3\envs\books\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] Le fichier spécifié est introuvable
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\HP\anaconda3\envs\books\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\HP\anaconda3\envs\books\lib\subprocess.py", line 493, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\HP\anaconda3\envs\books\lib\subprocess.py", line 858, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\HP\anaconda3\envs\books\lib\subprocess.py", line 1327, in _execute_child
# ...

# %%
distance
# Out:
# array([[ 0.        , 73.70888685, 74.13501197, 74.14849965, 74.25631286,
#         74.42445835]])

# %%
suggestion
# Out:
# array([[ 237, 1391, 1713,  770,   65,  284]], dtype=int64)

# %%
for i in range(len(suggestion)):
 print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Beloved (Plume Contemporary Fiction)', 'Reasonable Doubt',
#        'The Blooding', 'Ground Zero and Beyond', 'A Secret Affair',
#        'Blood and Gold (Rice, Anne, Vampire Chronicles.)'],
#       dtype='object', name='title')

# %%
book_name = book_pivot.index[237]
print(book_name)
# Out:
# Legacy of Silence

# %%
# keeping books name
book_name=book_pivot.index
book_name
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='title', length=2444)

# %%
#  book post URL
final_rating.head()
# Out:
#    User-ID        ISBN  rating                 title      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher                                              image  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    number of rating
# 0                60
# 1                60
# 2                60
# 3                60
# ...

# %%
np.where(book_pivot.index=='Flesh Tones: A Novel')[0][0]
# Out:
# 676

# %%
#final_rating ['tiltle'].vale_counts()
ids= np.where(final_rating['title']=="Flesh Tones: A Novel" )[0][0]

# %%
final_rating.iloc[ids]['image']
# Out:
# 'http://images.amazon.com/images/P/034545104X.01.LZZZZZZZ.jpg'

# %%
#getting all the books that are near the Legacy of Silence (index is 237)
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name
# Out:
# [Index(['Beloved (Plume Contemporary Fiction)', 'Reasonable Doubt',
#         'The Blooding', 'Ground Zero and Beyond', 'A Secret Affair',
#         'Blood and Gold (Rice, Anne, Vampire Chronicles.)'],
#        dtype='object', name='title')]

# %%
ids_index = []
for name in book_name[0]:
    ids= np.where(final_rating['title']== name )[0][0]
    ids_index.append(ids)

# %%
ids_index
# Out:
# [90174, 151941, 245368, 283065, 206289, 266299]

# %%
for i in ids_index:
    url = final_rating.iloc[i]['image']
    print(url)
# Out:
# http://images.amazon.com/images/P/0452264464.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0804107491.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0553282816.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/1401088945.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0061012289.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0345409329.01.LZZZZZZZ.jpg

# %%
# streamlit we will try to render in our app web
# artifact  refers to the output files or byproducts generated by your machine learning project.
import pickle

# %%
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_name,open('artifacts/books_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %% [markdown]
# # Testing Model

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion= model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)

    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books :
            if j== book_name:
                print(f"you searched '{book_name}'\n")
                print("the suggestion books are \n")
            else : 
                print(j)

# %%
book_name = "2nd Chance"
recommend_book(book_name)
# Out:
# you searched '2nd Chance'
#
# the suggestion books are
#
# Breaking Point (Tom Clancy's Net Force, No. 4)
# Cabin
# The Juror
# Ground Zero and Beyond
# Heaven

# %%
book_name = "Harry Potter and the Chamber of Secrets (Book 2)"
recommend_book(book_name)
